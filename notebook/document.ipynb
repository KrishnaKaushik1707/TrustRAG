# %% [markdown]
# ## Data ingestion:-
# 1. Understand Document Structure(page_content, metadata)
# 2. Load different typr of file formats(txt, pdf, directory etc)

# %%
### Document structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content='This is main text content I am using to create a RAG',
    metadata={
        'source':'example.txt',
        'pages':1,
        'author':'Krishna Kaushik',
        'data_created':'2026-08-24'
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Krishna Kaushik', 'data_created': '2026-08-24'}, page_content='This is main text content I am using to create a RAG')

# %% [markdown]
# ## Text Loader

# %%
## Create a simple txt file
import os
os.makedirs('../data/text_files',exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/text_files/python_intro.txt', encoding='utf-8')
document=loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %% [markdown]
# ## Directory Loader

# %%
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from directory
dir_loader = DirectoryLoader(
    '../data/text_files',
    glob='**/*.txt', ## Pattern to match files
    loader_cls=TextLoader
    )

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %% [markdown]
# ## Pdf Loader

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# %%
## load all pdf files from directory
pdf_loader = DirectoryLoader(
    '../data/pdf',
    glob='**/*.pdf', ## Pattern to match files
    loader_cls=PyMuPDFLoader
    )

pdf_documents=pdf_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'www.ilovepdf.com', 'creator': 'Microsoft® Word 2016', 'creationdate': '2026-05-13T07:48:19+00:00', 'source': '../data/pdf/Resume_Meghana.pdf', 'file_path': '../data/pdf/Resume_Meghana.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': 'Administrator', 'subject': '', 'keywords': '', 'moddate': '2026-05-13T07:48:19+00:00', 'trapped': '', 'modDate': 'D:20260513074819Z', 'creationDate': "D:20260513074819+00'00'", 'page': 0}, page_content='Meghana Perada                                                                                                 +91-8374955043 \nRoll No.:23011M2102                                                                                                       \nmeghanaperada9@gmail.com \nBachelor of Technology                                                                             linkedin.com/in/meghana-perada-035639348 \nJawaharlal Nehru Technological University, Hyderabad \n \nEDUCATIOn \n \n• Bachelor of Technology in Computer Science and Engineering \n2023-27 \nJawaharlal  Nehru  Technological  University , Hyderabd \nCGPA: 8.32 \nPERsonaL PROjECTs \n \n• RAG Document Q&A System \nDeveloped a high performance RAG system for intelligent document question-answering using hybrid semantic and keyword-based \nretrieval \n– Implemented FAISS and BM25-based hybrid retrieval to improve contextual relevance and answer accuracy. \n– Integrated multilingual embedding and reranking models to enhance document understanding and inference \ncapability. \n– Built scalable pipelines for processing multi-format documents including pdf,docx,pptx,xlsx,html,and images. \n– Optimized system performance using async processing,smart chunking,and persistent caching mechanisms. \n– Technology Used: Pyhton, FastAPI, PyTorch, FAISS, Langchain, BGE-M3, Docker, Pydantic \n• Stealth ZK-KYC –On chain ZK identity Protocol for Algorand \nDeveloped  a privacy preserving decentralized identity protocol for secure on-chain KYC verification using Zero-Knowledge Proofs. \n– Used Groth16- based zk proof verification for secure identity authentication without exposing sensitive user \ndata. \n– Built client side identity processing architecture eliminating centralized storage of personal identifiable \ninformation(PII). \n– Developed smart contracts for on-chain proof verification and Sybil resistant identity validation using anonymous \nnullifiers. \n– Technology Used: Next.js, TypeScript,  Algorand,  Circom,  SnarkJS,  Groth16, TailwindCSS ,  Algokit. \n• StegoShield-A secure data hiding system \nBuilt a web based image steganography application for securely hiding secret messages within images using the Least Significant \nBit(LSB) algorithm. \n– Implemented LSB-based steganography for secure message embedding and extraction in png and bmp image \nformats. \n– Built interactive encoding and decoding workfliows with real time image capacity analysis and visualization \nfeatures. \n– Technology Used : Python, Django,  Bootstrap 5, Three.js, Pillow(PIL), Javascript \nExPERIEncE \n \n• Heal Bharat Services  \nJan - Feb 2025 \nWeb Developer intern \nRemote - Hyderabad, Telangana, India \n– Contributed to the development of a realt-time health tips web platform with focus on responsive and user-\nfriendly design. \n– Designed and implemented landing pages optimized for accessibility,performance, and seamless user experience. \n– Collaborated with the development team to enhance frontend functionality and improve website responsiveness \nacross devices \n– Technology used:HTML,CSS,Javascript,Bootstrap,TailwindCSS \nTEChnICAL SKILLs and InTEREsTs \nLanguages: C/C++, Python, Java, TypeScript, Javascript, SQL \nFrameworks and Libraries : FastAPI,React,Next.js Pandas, Matplotlib, Numpy, Scipy, PyTorch, Langchain, etc. \nTools and Technologies: VS/VScode, Git, Github, Linux, Docker,AWS. \nRelevent Coursework: Data Structures & Algorithms, Algorithm Design & Analysis, Operating Systems, Object \nOr ...
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20260615112825', 'source': '../data/pdf/shyam resume.pdf', 'file_path': '../data/pdf/shyam resume.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': 'file.pdf', 'author': '', 'subject': '', 'keywords': '', 'moddate': 'D:20260615112825', 'trapped': '', 'modDate': 'D:20260615112825', 'creationDate': 'D:20260615112825', 'page': 0}, page_content='T.S.Shyam Ganeesh\nEmail:shyamganeesh2@gmail.com\nLinkedin: https://www.linkedin.com/in/shyam-ganeesh/\nMobile: +91-7780438293\nGitHub: https://github.com/Shyam1826\nABOUTME\nComputer Science Engineering student specializing in Full-Stack Web Development (MERN stack) with hands-on experience building secure,\nreal-time web applications and AI-powered systems. Developed and deployed 5+ projects, including an AI-based resume screening system\nusing NLP techniques. Strong foundation in RESTful APIs, authentication systems, database design, and collaborative development through\ninternships and hackathons.\nTECHNICAL SKILLS\n• Programming Languages: Java, C++, C, JavaScript, Python\n• Frontend : HTML, CSS, React.js\n• Backend : Node.js, Express.js\n• Databases: MongoDB, PostgreSQL\n• Web Concepts: REST APIs, Authentication & Authorization, CRUD Operations, HTTP, JSON\n• Tools: Git, GitHub, Postman, VS Code, Vercel\nPROJECTS\n• Adaptive Semi-Structured Dataset Reconstruction Engine\n-\nDeveloped an automated data preprocessing pipeline that eliminates manual cleaning overhead by delivering dual-intent outputs\noptimized for BI analytics and ML training workflows.\n-\nEngineered 4 heuristic-based recovery strategies (Segmented, Positional, Streaming, Hybrid) using row-signature analysis to instantly\nreconstruct broken, shifted, or OCR-corrupted datasets into flat tabular schemas.\n-\nIntegrated automated distribution tracking that handles missing data by dynamically switching to robust median imputation for highly\nskewed features (Skewness > 0.5) to eliminate outlier bias.\n-\nImplemented high-cardinality noise filtering and a Pearson Correlation matrix (r > 0.85) to automatically isolate and drop redundant\nmulti-collinear features based on their mathematical predictive strength.\n-\nBuilt a custom-styled Streamlit interface utilizing an in-memory session cache guard (st.session_state) for lag-free toggling between\nraw BI dashboards and encoded ML training matrices.\nTechnologies: Python, Pandas, NumPy, Regex, OOP, Data Reconstruction & Processing Algorithms, Machine Learning, Streamlit\n• Virtual Voting System (Full-Stack Web Application)\n-\nDeveloped a secure web-based voting platform with Voter, Candidate, and Admin roles\n-\nImplemented real-time voting updates using Socket.io\n-\nBuilt an admin dashboard to manage elections, candidates, and monitor real-time voting analytics\n-\nImplemented JWT-based authentication and role-based authorization for secure access\n-\nIntegrated frontend and backend for complete end-to-end functionality\n-\nDeployed project: https://virtual-voting.vercel.app/\n-\nGitHub:https://github.com/Shyam1826/virtual-voting.git\nTechnologies: React.js, Node.js, Express.js, MongoDB, Socket.io, Git\n• AI Resume Screening and Candidate Ranking System\n-\nBuilt an AI-based resume analysis system that ranks candidates against job descriptions\n-\nImplemented TF-IDF and cosine similarity, reducing manual screening time by ~50%\n-\nDeveloped an interactive recruiter dashboard using Streamlit for resume evaluation\n-\nParsed PDF resumes using Python libraries for automated data extraction\nTechnologies: Python, NLP, Streamlit, TF-IDF\nEXPERIENCE\n• INTERNSHIP EXPERIENCE\nAI: Transformative Learning Internship – TechSaksham (AICTE, Microsoft & SAP) Edunet Foundation | Feb 2025 – Mar 2025\n-\nDeveloped AI-based applications through project-based learning\n-\nImplemented NLP techniques for resume screening and similarity matching\n-\nCollaborated with mentors and peers to  ...
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20260615112825', 'source': '../data/pdf/shyam resume.pdf', 'file_path': '../data/pdf/shyam resume.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': 'file.pdf', 'author': '', 'subject': '', 'keywords': '', 'moddate': 'D:20260615112825', 'trapped': '', 'modDate': 'D:20260615112825', 'creationDate': 'D:20260615112825', 'page': 1}, page_content='CERTIFICATIONS\n• The Complete Web Development Bootcamp – Udemy\n(HTML, CSS, JavaScript, React.js, Node.js, Express.js, MongoDB)\nACHIEVEMENTS\n• Secured Top 29 position out of 1500 teams in Bajaj Finserv HackRx 6.0, showcasing expertise in innovative problem-solving and technical\nimplementation.\n• Built and deployed multiple full-stack and AI-based projects\nLANGUAGES\n• Tamil: Native\n• English: Proficient\n• Telugu: Fluent\n• Hindi: Fluent'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20260615112825', 'source': '../data/pdf/shyam resume.pdf', 'file_path': '../data/pdf/shyam resume.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': 'file.pdf', 'author': '', 'subject': '', 'keywords': '', 'moddate': 'D:20260615112825', 'trapped': '', 'modDate': 'D:20260615112825', 'creationDate': 'D:20260615112825', 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2026-06-15T11:18:02+00:00', 'source': '../data/pdf/Kaushik_ML_Resume.pdf', 'file_path': '../data/pdf/Kaushik_ML_Resume.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Live Demo: .https://breast-cancer-classification-bpfmvhv4waqtxp2c2knn8d.streamlit.app/', 'author': 'Krishna Kaushik', 'subject': '', 'keywords': 'DAHMoWHNNqI,BAGa86N5nu4,0', 'moddate': '2026-06-15T11:18:02+00:00', 'trapped': '', 'modDate': "D:20260615111802+00'00'", 'creationDate': "D:20260615111802+00'00'", 'page': 0}, page_content='V KRISHNA KAUSHIK\nTech Stack: Python, Scikit-learn, Streamlit, Pandas, OpenWeatherMap API\nBuilt an ML-powered dynamic pricing engine that predicts real-\ntime price multipliers based on demand, weather, time, and\nlocation data.\nCompared 5 regression models using RandomizedSearchCV with\ncross-validation, achieving R² of 0.89 with Gradient Boosting.\nBuilt and deployed an interactive Streamlit dashboard with live\nweather API integration and dynamic pricing visualization.\n \nLive Demo: https://surge-pricing-kaushik1707.streamlit.app/\nGitHub: https://github.com/KrishnaKaushik1707/surge_pricing_engine\nTech Stack: Python, Scikit-learn, Pickle, Pandas, Numpy, Streamlit \nDeveloped an ML-powered healthcare application using Scikit-\nlearn and Streamlit.\nAchieved 96.48% classification accuracy in distinguishing benign\nfrom malignant tumors using a Scikit-learn model.\nDeployed the application on Streamlit Cloud for public access.\nLive Demo: https://cancer-classification-kaushik1707.streamlit.app/\n+91-7075627439 \nvkrishnakaushik@gmail.com\nhttps://www.linkedin.com/in/krishna-kaushik-097884333/\nhttps://github.com/KrishnaKaushik1707\nEnglish | Telugu | Hindi\nPROJECTS\nSUMMARY\n \nCERTIFICATES\n \nSKILLS\nProgramming Languages: \n• JavaScript\n• Python\nWeb Development:\n• React.js\n• Node.js\n• Express.js\n• MongoDB\n• HTML\n• CSS\nMachine Learning:\n• Hyperparameter Tuning\n• NLP\n• Data Preprocessing\n• Scikit-learn\n• Pandas\n• NumPy\nTools & Platforms:\n• Git\n• GitHub\n• Postman\n• VS Code\nCore Concepts:\n• OOPs\n• DBMS\n• Operating Systems\n• Computer Networks\nEDUCATION\n \nLANGUAGES\nJNTUH College of Engineering Hyderabad\nB.Tech in Computer Science Engineering\n(AIML)\n2023-2027\nSGPA: 8.83 (latest semester)\nNarayana Jr College\nIntermediate (MPC)\nPercentage: 93%\nBharatiya Vidya Bhavans ARR School\nCBSE\nPercentage: 86%\nSurge Pricing Engine\nBreast Cancer Prediction System\nFinal-year AI/ML engineering student with hands-on experience across\nthe full machine learning lifecycle — data preprocessing, feature\nengineering, model selection, hyperparameter tuning, and deployment.\nBuilt and deployed end-to-end ML systems. Proficient in Python, Scikit-\nlearn, Pandas, and NumPy, with a strong interest in applying ML to solve\nreal-world, data-driven problems.\nThe complete Web Development Bootcamp by\nApna College(Sigma 6.0)\nGitHub: https://github.com/KrishnaKaushik1707/Breast-Cancer-\nClassification'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2026-08-18T18:07:48+00:00', 'source': '../data/pdf/Kaushik_ML_DEV_Resume.pdf', 'file_path': '../data/pdf/Kaushik_ML_DEV_Resume.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Kaushik_ML_DEV_Resume.pdf', 'author': 'Krishna Kaushik', 'subject': '', 'keywords': 'DAHSqdFyy2s,BAGa86N5nu4', 'moddate': '2026-08-18T18:07:48+00:00', 'trapped': '', 'modDate': "D:20260818180748+00'00'", 'creationDate': "D:20260818180748+00'00'", 'page': 0}, page_content='V KRISHNA KAUSHIK\nTech Stack: React.js, Bootstrap, MongoDB, Express.js, Node.js\nBuilt a responsive stock trading dashboard using React.js\nand reusable components.\nDeveloped a REST APIs using Node.js and Express.js and\nintegrated MongoDB for data storage.\nDesigned clean, user-friendly UI for watchlist and\nportfolio-style views.\n \nLive Demo: https://tradingsphere.netlify.app/\nGitHub: https://github.com/KrishnaKaushik1707/Zerodha-clone\nTech Stack: React.js, Node.js, Python, Machine Learning\nDeveloped an ML-powered healthcare application using Scikit-\nlearn and Streamlit.\nBuilt an interactive dashboard for real-time tumor classification\n(Benign/Malignant).\nDeployed the application on Streamlit Cloud for public access.\nGitHub: .https://github.com/KrishnaKaushik1707/Breast-Cancer-\nClassification.git\n+91-7075627439 \nkk9369205@gmail.com\nhttps://www.linkedin.com/in/krishna-kaushik-097884333/\nhttps://github.com/KrishnaKaushik1707\nEnglish | Telugu | Hindi\nPROJECTS\nSUMMARY\n \nCERTIFICATES\n \nSKILLS \nProgramming Languages:\n• C++\n• JavaScript\n• Python\nWeb Development:\n• React.js\n• Node.js\n• Express.js\n• MongoDB\n• HTML\n• CSS\nMachine Learning:\n• Machine Learning\n• NLP\n• Data Preprocessing\n• Scikit-learn\n• Pandas\n• NumPy\nTools & Platforms:\n• Git\n• GitHub\n• Postman\n• VS Code\nCore Concepts:\n• OOPs\n• DBMS\n• Operating Systems\n• Computer Networks\nEDUCATION\n \nLANGUAGES\nJNTUH College of Engineering Hyderabad\nB.Tech in Computer Science Engineering\n(AI/ML)\n2023-2027\nSGPA: 8.87 (latest semester 3-1)\nNarayana Jr College\nIntermediate (MPC)\nPercentage: 93%\nBharatiya Vidya Bhavans ARR School\nCBSE\nPercentage: 86%\nTrade Sphere\nBreast Cancer Prediction System\nPassionate AIML student with strong foundations in machine learning,\nfull-stack web development, and problem solving. Interested in building\nAI-powered applications and scalable software solutions using modern\ntechnologies. Seeking opportunities to apply AI/ML and development\nskills in real-world projects.\nThe complete Web Development Bootcamp by\nApna College(Sigma 6.O)')]
